# %%
# Importing necessary libraries
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Actual and predicted values for evaluation
actual = np.array(['Positive', 'Negative', 'Positive', 'Positive', 'Negative', 'Negative', 'Positive', 'Positive', 'Negative', 'Negative'])
predicted = np.array(['Positive', 'Negative', 'Negative', 'Positive', 'Negative', 'Positive', 'Positive', 'Positive', 'Positive', 'Negative'])

# %%
# Compute confusion matrix by comparing actual and predicted values
matrix = confusion_matrix(actual, predicted)

# %%
# Visualize the confusion matrix using a heatmap
sns.heatmap(
    matrix,
    annot=True,
    fmt='g',
    xticklabels=['Positive', 'Negative'],
    yticklabels=['Positive', 'Negative']
)

plt.ylabel('Actual', fontsize=12)
plt.xlabel('Predicted', fontsize=12)
plt.title('Confusion Matrix', fontsize=17)
plt.show()

# %%
# Labeling the axes and adding a title to the confusion matrix plot
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy = accuracy_score(actual, predicted)
print('Accuracy:', accuracy)

precision = precision_score(actual, predicted, average='weighted')
print('Precision:', precision)

recall = recall_score(actual, predicted, average='weighted')
print('Recall:', recall)

f1 = f1_score(actual, predicted, average='weighted')
print('F1 Score:', f1)
# Out:
# Accuracy: 0.7
# Precision: 0.7083333333333333
# Recall: 0.7
# F1 Score: 0.696969696969697
